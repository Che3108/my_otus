# %%
pip install h2o
# Out:
# Requirement already satisfied: h2o in /home/slawa/HDD/my_scripts/my_otus/ML_advanced/venv/lib/python3.11/site-packages (3.46.0.1)
# Requirement already satisfied: requests in /home/slawa/HDD/my_scripts/my_otus/ML_advanced/venv/lib/python3.11/site-packages (from h2o) (2.31.0)
# Requirement already satisfied: tabulate in /home/slawa/HDD/my_scripts/my_otus/ML_advanced/venv/lib/python3.11/site-packages (from h2o) (0.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/slawa/HDD/my_scripts/my_otus/ML_advanced/venv/lib/python3.11/site-packages (from requests->h2o) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/slawa/HDD/my_scripts/my_otus/ML_advanced/venv/lib/python3.11/site-packages (from requests->h2o) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/slawa/HDD/my_scripts/my_otus/ML_advanced/venv/lib/python3.11/site-packages (from requests->h2o) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/slawa/HDD/my_scripts/my_otus/ML_advanced/venv/lib/python3.11/site-packages (from requests->h2o) (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# https://github.com/h2oai/h2o-tutorials/blob/master/tutorials/sklearn-integration/H2OAutoML_as_sklearn_estimator.ipynb
import h2o
from h2o.automl import H2OAutoML
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321. connected.
# --------------------------  -----------------------------
# H2O_cluster_uptime:         3 mins 38 secs
# H2O_cluster_timezone:       Asia/Irkutsk
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.46.0.1
# H2O_cluster_version_age:    11 days
# H2O_cluster_name:           H2O_from_python_slawa_ivcgx7
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    3.429 Gb
# H2O_cluster_total_cores:    12
# H2O_cluster_allowed_cores:  12
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.11.8 final
# --------------------------  -----------------------------

# %%
# Вариант запуска № 2 с использованием sklearn:
from sklearn.datasets import load_wine
import pandas as pd
from h2o.sklearn import H2OAutoMLClassifier
from sklearn.model_selection import train_test_split
wine = load_wine()
X = wine.data
y=wine.target

aml_c = H2OAutoMLClassifier(max_models=20, seed=1, max_runtime_secs=10)
X_train, X_test, y_train, y_test = train_test_split(X, y)

aml_c.fit(X=X_train, y=y_train)
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |███
# 18:34:59.291: _min_rows param, The dataset size is too small to split for min_rows=100.0: must have at least 200.0 (weighted) rows, but have only 133.0.
#
# ████████████████████████████████████████████████████████████| (done) 100%
# H2OAutoMLClassifier(max_models=20, max_runtime_secs=10, seed=1)

# %%
preds = aml_c.predict(X_test)
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# glm prediction progress: |
# ███████████████████████████████████████████████████████| (done) 100%
# /home/slawa/HDD/my_scripts/my_otus/ML_advanced/venv/lib/python3.11/site-packages/h2o/frame.py:1983: H2ODependencyWarning: Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using multi-thread, install datatable (for Python 3.9 or lower), or polars and pyarrow (for Python 3.10 or above) and activate it using:
#
# with h2o.utils.threading.local_context(polars_enabled=True, datatable_enabled=True):
#     pandas_df = h2o_df.as_data_frame()
#
#   warnings.warn("Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using"

# %%
preds
# Out:
# array([1, 2, 1, 0, 1, 0, 2, 0, 0, 2, 0, 0, 0, 2, 0, 0, 2, 2, 0, 2, 2, 2,
#        1, 2, 0, 2, 1, 2, 0, 2, 0, 1, 1, 2, 1, 2, 2, 2, 1, 1, 1, 0, 0, 1,
#        2])

# %%
y_test
# Out:
# array([1, 2, 1, 0, 1, 0, 2, 0, 0, 2, 0, 0, 0, 2, 0, 0, 2, 2, 0, 2, 2, 2,
#        1, 2, 0, 2, 1, 2, 0, 2, 0, 1, 1, 2, 1, 2, 2, 2, 1, 1, 1, 0, 0, 1,
#        2])

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       1.00      1.00      1.00        12
#            2       1.00      1.00      1.00        18
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %%
aml_c.estimator.leaderboard
# Out:
# model_id                                           mean_per_class_error    logloss      rmse        mse
# -----------------------------------------------  ----------------------  ---------  --------  ---------
# GLM_1_AutoML_1_20240324_183457                               0.00564972  0.0580312  0.115342  0.0133037
# XRT_1_AutoML_1_20240324_183457                               0.0112994   0.148035   0.182476  0.0332976
# GBM_3_AutoML_1_20240324_183457                               0.0169492   0.0549668  0.130234  0.016961
# DRF_1_AutoML_1_20240324_183457                               0.0169492   0.145694   0.184262  0.0339524
# XGBoost_grid_1_AutoML_1_20240324_183457_model_1              0.0169492   0.204539   0.223149  0.0497955
# GBM_4_AutoML_1_20240324_183457                               0.0169492   0.0497016  0.131494  0.0172908
# GBM_2_AutoML_1_20240324_183457                               0.0169492   0.0458734  0.125693  0.0157987
# GBM_5_AutoML_1_20240324_183457                               0.0169492   0.0455794  0.124532  0.0155083
# XGBoost_3_AutoML_1_20240324_183457                           0.0225989   0.135438   0.185226  0.0343085
# XGBoost_2_AutoML_1_20240324_183457                           0.0245249   0.206363   0.226108  0.051125
# [13 rows x 5 columns]
